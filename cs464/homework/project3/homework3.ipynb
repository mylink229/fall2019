# %%
from sklearn.ensemble import RandomForestClassifier 
from sklearn import tree
from sklearn.impute import SimpleImputer
import numpy
import pandas as panda
from sklearn.model_selection import train_test_split

##########
# TASK 1 #
##########
column_names = ['age', 'workclass', 'education', 'marital-status', 
            'occupation', 'relationship', 'race', 'sex', 'capital-gain', 
            'capital-loss', 'hours-per-week', 'native-country', '50k']
#trainDataFrame = panda.read_csv("/home/chufu/Documents/fall2019/cs464/homework/project3/census-data/adult_train.txt", sep = ",", header = None, names = ["age", "workclass", "education", "marital-status", "occupation", "relationship", "race", "sex", "capital-gain", "capital-loss", "hours-per-week", "native-country"])
#testDataFrame = panda.read_csv("/home/chufu/Documents/fall2019/cs464/homework/project3/census-data/adult_test.txt", sep = ",", header = None, names = ["age", "workclass", "education", "marital-status", "occupation", "relationship", "race", "sex", "capital-gain", "capital-loss", "hours-per-week", "native-country"])
trainDataFrame = panda.read_csv("/home/chufu/Documents/fall2019/cs464/homework/project3/census-data/adult_train.txt", header = None, na_values=" ?").copy()
testDataFrame = panda.read_csv("/home/chufu/Documents/fall2019/cs464/homework/project3/census-data/adult_test.txt", header = None, na_values= " ?").copy()
#featuresDataFrame = panda.read_csv("/home/chufu/Documents/fall2019/cs464/homework/project3/census-data/features.txt", sep = "\t", engine="python", header = None)
featuresDataFrame = panda.read_csv("/home/chufu/Documents/fall2019/cs464/homework/project3/census-data/features.txt", sep = ":,|_", engine="python", header = None).copy()
trainDataFrame.columns = column_names
testDataFrame.columns = column_names

trainWorkclassMode = trainDataFrame["workclass"].mode()
trainOccupationMode = trainDataFrame["occupation"].mode()
trainNativeCountryMode = trainDataFrame["native-country"].mode()

trainDataFrame["workclass"].fillna(trainWorkclassMode, inplace = True)
trainDataFrame["occupation"].fillna(trainOccupationMode, inplace = True)
trainDataFrame["native-country"].fillna(trainNativeCountryMode, inplace = True)

# %%
##########
# TASK 2 #
##########
new_feature_values = []
j = 0
for i in trainDataFrame["age"]:
    if trainDataFrame.at[j, "age"] == " ?":
        item = ["age", 0]
        new_feature_values.append(item)
    else:
        item = ["age", trainDataFrame.at[j, "age"]]
        new_feature_values.append(item)
    j+=1

j = 0
for i in trainDataFrame["workclass"]:
    if trainDataFrame.at[j, "workclass"] == " ?":
        item = ["workclass", 0]
        new_feature_values.append(item)
    else:
        item = ["workclass", 1]
        new_feature_values.append(item)
    j+=1

j = 0
for i in trainDataFrame["education"]:
    if trainDataFrame.at[j, "education"] == " ?":
        item = ["education", 0]
        new_feature_values.append(item)
    else:
        item = ["education", 1]
        new_feature_values.append(item)
    j+=1

j = 0
for i in trainDataFrame["marital-status"]:
    if trainDataFrame.at[j, "marital-status"] == " ?":
        item = ["marital-status", 0]
        new_feature_values.append(item)
    else:
        item = ["marital-status", 1]
        new_feature_values.append(item)
    j+=1

j = 0
for i in trainDataFrame["occupation"]:
    if trainDataFrame.at[j, "occupation"] == " ?":
        item = ["occupation", 0]
        new_feature_values.append(item)
    else:
        item = ["occupation", 1]
        new_feature_values.append(item)
    j+=1

j = 0
for i in trainDataFrame["relationship"]:
    if trainDataFrame.at[j, "relationship"] == " ?":
        item = ["relationship", 0]
        new_feature_values.append(item)
    else:
        item = ["relationship", 1]
        new_feature_values.append(item)
    j+=1

j = 0
for i in trainDataFrame["race"]:
    if trainDataFrame.at[j, "race"] == " ?":
        item = ["race", 0]
        new_feature_values.append(item)
    else:
        item = ["race", 1]
        new_feature_values.append(item)
    j+=1

j = 0
for i in trainDataFrame["sex"]:
    if trainDataFrame.at[j, "sex"] == " ?":
        item = ["sex", 0]
        new_feature_values.append(item)
    else:
        item = ["sex", 1]
        new_feature_values.append(item)
    j+=1

j = 0
for i in trainDataFrame["capital-gain"]:
    if trainDataFrame.at[j, "capital-gain"] == " ?":
        item = ["capital-gain", trainDataFrame.at[j, "capital-gain"]]
        new_feature_values.append(item)
    else:
        item = ["capital-gain", trainDataFrame.at[j, "capital-gain"]]
        new_feature_values.append(item)
    j+=1

j = 0
for i in trainDataFrame["capital-loss"]:
    if trainDataFrame.at[j, "capital-loss"] == " ?":
        item = ["capital-loss", trainDataFrame.at[j, "capital-loss"]]
        new_feature_values.append(item)
    else:
        item = ["capital-loss", 1]
        new_feature_values.append(item)
    j+=1

j = 0
for i in trainDataFrame["hours-per-week"]:
    if trainDataFrame.at[j, "hours-per-week"] == " ?":
        item = ["hours-per-week", trainDataFrame.at[j, "hours-per-week"]]
        new_feature_values.append(item)
    else:
        item = ["hours-per-week", trainDataFrame.at[j, "hours-per-week"]]
        new_feature_values.append(item)
    j+=1

j = 0
for i in trainDataFrame["50k"]:
    if trainDataFrame.at[j, "50k"] == " ?":
        item = ["50k", trainDataFrame.at[j, "50k"]]
        new_feature_values.append(item)
    else:
        item = ["50k", trainDataFrame.at[j, "50k"]]
        new_feature_values.append(item)
    j+=1
    
    
#test = train_test_split(
#    new_feature_values,
 #   trainDataFrame,
 #   train_size = 0.70,
  #  test_size = 0.30,
   # random_state = 85
    #)

# %%
len(new_feature_values)
new_feature_values
# Out:
# [['age', 39],
#  ['age', 50],
#  ['age', 38],
#  ['age', 53],
#  ['age', 28],
#  ['age', 37],
#  ['age', 49],
#  ['age', 52],
#  ['age', 31],
#  ['age', 42],
#  ['age', 37],
#  ['age', 30],
#  ['age', 23],
#  ['age', 32],
#  ['age', 40],
#  ['age', 34],
#  ['age', 25],
#  ['age', 32],
#  ['age', 38],
#  ['age', 43],
#  ['age', 40],
#  ['age', 54],
#  ['age', 35],
#  ['age', 43],
#  ['age', 59],
#  ['age', 56],
#  ['age', 19],
#  ['age', 54],
#  ['age', 39],
#  ['age', 49],
#  ['age', 23],
#  ['age', 20],
#  ['age', 45],
#  ['age', 30],
#  ['age', 22],
#  ['age', 48],
#  ['age', 21],
#  ['age', 19],
#  ['age', 31],
#  ['age', 48],
#  ['age', 31],
#  ['age', 53],
#  ['age', 24],
#  ['age', 49],
#  ['age', 25],
#  ['age', 57],
#  ['age', 53],
#  ['age', 44],
#  ['age', 41],
#  ['age', 29],
#  ['age', 25],
#  ['age', 18],
#  ['age', 47],
#  ['age', 50],
#  ['age', 47],
#  ['age', 43],
#  ['age', 46],
#  ['age', 35],
#  ['age', 41],
#  ['age', 30],
#  ['age', 30],
#  ['age', 32],
#  ['age', 48],
#  ['age', 42],
#  ['age', 29],
#  ['age', 36],
#  ['age', 28],
#  ['age', 53],
#  ['age', 49],
#  ['age', 25],
#  ['age', 19],
#  ['age', 31],
#  ['age', 29],
#  ['age', 23],
#  ['age', 79],
#  ['age', 27],
#  ['age', 40],
#  ['age', 67],
#  ['age', 18],
#  ['age', 31],
#  ['age', 18],
#  ['age', 52],
#  ['age', 46],
#  ['age', 59],
#  ['age', 44],
#  ['age', 53],
#  ['age', 49],
#  ['age', 33],
#  ['age', 30],
#  ['age', 43],
#  ['age', 57],
#  ['age', 37],
#  ['age', 28],
#  ['age', 30],
#  ['age', 34],
#  ['age', 29],
#  ['age', 48],
#  ['age', 37],
#  ['age', 48],
#  ['age', 32],
#  ['age', 76],
#  ['age', 44],
#  ['age', 47],
#  ['age', 20],
#  ['age', 29],
#  ['age', 32],
#  ['age', 17],
#  ['age', 30],
#  ['age', 31],
#  ['age', 42],
#  ['age', 24],
#  ['age', 38],
#  ['age', 56],
#  ['age', 28],
#  ['age', 36],
#  ['age', 53],
#  ['age', 56],
#  ['age', 49],
#  ['age', 55],
#  ['age', 22],
#  ['age', 21],
#  ['age', 40],
#  ['age', 30],
#  ['age', 29],
#  ['age', 19],
#  ['age', 47],
#  ['age', 20],
#  ['age', 31],
#  ['age', 35],
#  ['age', 39],
#  ['age', 28],
#  ['age', 24],
#  ['age', 38],
#  ['age', 37],
#  ['age', 46],
#  ['age', 38],
#  ['age', 43],
#  ['age', 27],
#  ['age', 20],
#  ['age', 49],
#  ['age', 61],
#  ['age', 27],
#  ['age', 19],
#  ['age', 45],
#  ['age', 70],
#  ['age', 31],
#  ['age', 22],
#  ['age', 36],
#  ['age', 64],
#  ['age', 43],
#  ['age', 47],
#  ['age', 34],
#  ['age', 33],
#  ['age', 21],
#  ['age', 52],
#  ['age', 48],
#  ['age', 23],
#  ['age', 71],
#  ['age', 29],
#  ['age', 42],
#  ['age', 68],
#  ['age', 25],
#  ['age', 44],
#  ['age', 28],
#  ['age', 45],
#  ['age', 36],
#  ['age', 39],
#  ['age', 46],
#  ['age', 18],
#  ['age', 66],
#  ['age', 27],
#  ['age', 28],
#  ['age', 51],
#  ['age', 27],
#  ['age', 28],
#  ['age', 27],
#  ['age', 21],
#  ['age', 34],
#  ['age', 18],
#  ['age', 33],
#  ['age', 44],
#  ['age', 43],
#  ['age', 30],
#  ['age', 40],
#  ['age', 37],
#  ['age', 34],
#  ['age', 41],
#  ['age', 53],
#  ['age', 31],
#  ['age', 58],
#  ['age', 38],
#  ['age', 24],
#  ['age', 41],
#  ['age', 47],
#  ['age', 41],
#  ['age', 23],
#  ['age', 36],
#  ['age', 40],
#  ['age', 35],
#  ['age', 24],
#  ['age', 26],
#  ['age', 19],
#  ['age', 51],
#  ['age', 42],
#  ['age', 37],
#  ['age', 18],
#  ['age', 36],
#  ['age', 35],
#  ['age', 58],
#  ['age', 17],
#  ['age', 44],
#  ['age', 37],
#  ['age', 35],
#  ['age', 60],
#  ['age', 54],
#  ['age', 37],
#  ['age', 50],
#  ['age', 38],
#  ['age', 45],
#  ['age', 25],
#  ['age', 31],
#  ['age', 64],
#  ['age', 90],
#  ['age', 54],
#  ['age', 53],
#  ['age', 18],
#  ['age', 60],
#  ['age', 66],
#  ['age', 75],
#  ['age', 65],
#  ['age', 35],
#  ['age', 41],
#  ['age', 25],
#  ['age', 33],
#  ['age', 28],
#  ['age', 59],
#  ['age', 40],
#  ['age', 41],
#  ['age', 38],
#  ['age', 23],
#  ['age', 40],
#  ['age', 41],
#  ['age', 24],
#  ['age', 20],
#  ['age', 38],
#  ['age', 56],
#  ['age', 58],
#  ['age', 32],
#  ['age', 40],
#  ['age', 45],
#  ['age', 41],
#  ['age', 42],
#  ['age', 59],
#  ['age', 19],
#  ['age', 58],
#  ['age', 42],
#  ['age', 20],
#  ['age', 32],
#  ['age', 45],
#  ['age', 50],
#  ['age', 36],
#  ['age', 45],
#  ['age', 17],
#  ['age', 59],
#  ['age', 26],
#  ['age', 37],
#  ['age', 19],
#  ['age', 64],
#  ['age', 33],
#  ['age', 33],
#  ['age', 61],
#  ['age', 17],
#  ['age', 50],
#  ['age', 27],
#  ['age', 30],
#  ['age', 43],
#  ['age', 44],
#  ['age', 35],
#  ['age', 25],
#  ['age', 24],
#  ['age', 22],
#  ['age', 42],
#  ['age', 34],
#  ['age', 60],
#  ['age', 21],
#  ['age', 57],
#  ['age', 41],
#  ['age', 50],
#  ['age', 25],
#  ['age', 50],
#  ['age', 36],
#  ['age', 31],
#  ['age', 29],
#  ['age', 21],
#  ['age', 27],
#  ['age', 65],
#  ['age', 37],
#  ['age', 39],
#  ['age', 24],
#  ['age', 38],
#  ['age', 48],
#  ['age', 21],
#  ['age', 31],
#  ['age', 55],
#  ['age', 24],
#  ['age', 43],
#  ['age', 26],
#  ['age', 46],
#  ['age', 35],
#  ['age', 41],
#  ['age', 26],
#  ['age', 34],
#  ['age', 19],
#  ['age', 36],
#  ['age', 22],
#  ['age', 24],
#  ['age', 77],
#  ['age', 22],
#  ['age', 29],
#  ['age', 62],
#  ['age', 39],
#  ['age', 43],
#  ['age', 35],
#  ['age', 29],
#  ['age', 76],
#  ['age', 63],
#  ['age', 23],
#  ['age', 43],
#  ['age', 58],
#  ['age', 66],
#  ['age', 41],
#  ['age', 26],
#  ['age', 47],
#  ['age', 55],
#  ['age', 53],
#  ['age', 17],
#  ['age', 30],
#  ['age', 49],
#  ['age', 19],
#  ['age', 45],
#  ['age', 26],
#  ['age', 38],
#  ['age', 36],
#  ['age', 33],
#  ['age', 22],
#  ['age', 43],
#  ['age', 67],
#  ['age', 30],
#  ['age', 56],
#  ['age', 31],
#  ['age', 33],
#  ['age', 26],
#  ['age', 33],
#  ['age', 46],
#  ['age', 59],
#  ['age', 38],
#  ['age', 65],
#  ['age', 40],
#  ['age', 42],
#  ['age', 26],
#  ['age', 36],
#  ['age', 62],
#  ['age', 43],
#  ['age', 43],
#  ['age', 22],
#  ['age', 28],
#  ['age', 56],
#  ['age', 22],
#  ['age', 57],
#  ['age', 39],
#  ['age', 26],
#  ['age', 17],
#  ['age', 40],
#  ['age', 45],
#  ['age', 44],
#  ['age', 20],
#  ['age', 33],
#  ['age', 23],
#  ['age', 46],
#  ['age', 38],
#  ['age', 54],
#  ['age', 46],
#  ['age', 25],
#  ['age', 46],
#  ['age', 36],
#  ['age', 23],
#  ['age', 29],
#  ['age', 44],
#  ['age', 19],
#  ['age', 19],
#  ['age', 35],
#  ['age', 27],
#  ['age', 46],
#  ['age', 34],
#  ['age', 34],
#  ['age', 44],
#  ['age', 45],
#  ['age', 20],
#  ['age', 25],
#  ['age', 52],
#  ['age', 20],
#  ['age', 28],
#  ['age', 50],
#  ['age', 34],
#  ['age', 28],
#  ['age', 41],
#  ['age', 28],
#  ['age', 46],
#  ['age', 28],
#  ['age', 32],
#  ['age', 41],
#  ['age', 24],
#  ['age', 33],
#  ['age', 46],
#  ['age', 31],
#  ['age', 35],
#  ['age', 52],
#  ['age', 30],
#  ['age', 34],
#  ['age', 34],
#  ['age', 20],
#  ['age', 17],
#  ['age', 32],
#  ['age', 29],
#  ['age', 33],
#  ['age', 25],
#  ['age', 36],
#  ['age', 23],
#  ['age', 63],
#  ['age', 47],
#  ['age', 80],
#  ['age', 17],
#  ['age', 40],
#  ['age', 30],
#  ['age', 27],
#  ['age', 33],
#  ['age', 34],
#  ['age', 34],
#  ['age', 23],
#  ['age', 42],
#  ['age', 29],
#  ['age', 45],
#  ['age', 24],
#  ['age', 44],
#  ['age', 27],
#  ['age', 20],
#  ['age', 44],
#  ['age', 51],
#  ['age', 20],
#  ['age', 17],
#  ['age', 19],
#  ['age', 45],
#  ['age', 60],
#  ['age', 42],
#  ['age', 44],
#  ['age', 40],
#  ['age', 30],
#  ['age', 38],
#  ['age', 23],
#  ['age', 32],
#  ['age', 44],
#  ['age', 54],
#  ['age', 32],
#  ['age', 50],
#  ['age', 24],
#  ['age', 37],
#  ['age', 52],
#  ['age', 38],
#  ['age', 49],
#  ['age', 30],
#  ['age', 60],
#  ['age', 22],
#  ['age', 35],
#  ['age', 30],
#  ['age', 67],
#  ['age', 46],
#  ['age', 17],
#  ['age', 22],
#  ['age', 27],
#  ['age', 23],
#  ['age', 33],
#  ['age', 43],
#  ['age', 28],
#  ['age', 41],
#  ['age', 52],
#  ['age', 25],
#  ['age', 63],
#  ['age', 59],
#  ['age', 45],
#  ['age', 38],
#  ['age', 40],
#  ['age', 46],
#  ['age', 35],
#  ['age', 34],
#  ['age', 33],
#  ['age', 41],
#  ['age', 20],
#  ['age', 23],
#  ['age', 26],
#  ['age', 72],
#  ['age', 23],
#  ['age', 62],
#  ['age', 52],
#  ['age', 58],
#  ['age', 25],
#  ['age', 24],
#  ['age', 19],
#  ['age', 43],
#  ['age', 47],
#  ['age', 39],
#  ['age', 49],
#  ['age', 53],
#  ['age', 32],
#  ['age', 34],
#  ['age', 28],
#  ['age', 57],
#  ['age', 25],
#  ['age', 20],
#  ['age', 21],
#  ['age', 34],
#  ['age', 38],
#  ['age', 50],
#  ['age', 24],
#  ['age', 37],
#  ['age', 44],
#  ['age', 28],
#  ['age', 42],
#  ['age', 74],
#  ['age', 38],
#  ['age', 44],
#  ['age', 44],
#  ['age', 26],
#  ['age', 36],
#  ['age', 41],
#  ['age', 67],
#  ['age', 39],
#  ['age', 57],
#  ['age', 29],
#  ['age', 31],
#  ['age', 34],
#  ['age', 44],
#  ['age', 29],
#  ['age', 30],
#  ['age', 27],
#  ['age', 27],
#  ['age', 32],
#  ['age', 58],
#  ['age', 35],
#  ['age', 21],
#  ['age', 28],
#  ['age', 46],
#  ['age', 36],
#  ['age', 72],
#  ['age', 35],
#  ['age', 33],
#  ['age', 69],
#  ['age', 35],
#  ['age', 31],
#  ['age', 34],
#  ['age', 30],
#  ['age', 28],
#  ['age', 54],
#  ['age', 47],
#  ['age', 24],
#  ['age', 52],
#  ['age', 20],
#  ['age', 43],
#  ['age', 45],
#  ['age', 29],
#  ['age', 47],
#  ['age', 24],
#  ['age', 51],
#  ['age', 17],
#  ['age', 37],
#  ['age', 27],
#  ['age', 29],
#  ['age', 18],
#  ['age', 36],
#  ['age', 58],
#  ['age', 26],
#  ['age', 65],
#  ['age', 57],
#  ['age', 59],
#  ['age', 27],
#  ['age', 31],
#  ['age', 21],
#  ['age', 29],
#  ['age', 18],
#  ['age', 52],
#  ['age', 57],
#  ['age', 42],
#  ['age', 55],
#  ['age', 60],
#  ['age', 31],
#  ['age', 23],
#  ['age', 27],
#  ['age', 23],
#  ['age', 42],
#  ['age', 25],
#  ['age', 49],
#  ['age', 32],
#  ['age', 19],
#  ['age', 60],
#  ['age', 42],
#  ['age', 35],
#  ['age', 48],
#  ['age', 51],
#  ['age', 29],
#  ['age', 36],
#  ['age', 17],
#  ['age', 52],
#  ['age', 24],
#  ['age', 24],
#  ['age', 26],
#  ['age', 27],
#  ['age', 39],
#  ['age', 30],
#  ['age', 50],
#  ['age', 52],
#  ['age', 46],
#  ['age', 23],
#  ['age', 45],
#  ['age', 65],
#  ['age', 29],
#  ['age', 47],
#  ['age', 30],
#  ['age', 34],
#  ['age', 38],
#  ['age', 33],
#  ['age', 49],
#  ['age', 47],
#  ['age', 49],
#  ['age', 43],
#  ['age', 30],
#  ['age', 58],
#  ['age', 19],
#  ['age', 21],
#  ['age', 33],
#  ['age', 47],
#  ['age', 52],
#  ['age', 26],
#  ['age', 60],
#  ['age', 21],
#  ['age', 36],
#  ['age', 31],
#  ['age', 50],
#  ['age', 31],
#  ['age', 71],
#  ['age', 58],
#  ['age', 30],
#  ['age', 20],
#  ['age', 24],
#  ['age', 35],
#  ['age', 38],
#  ['age', 27],
#  ['age', 29],
#  ['age', 70],
#  ['age', 34],
#  ['age', 44],
#  ['age', 43],
#  ['age', 44],
#  ['age', 35],
#  ['age', 27],
#  ['age', 43],
#  ['age', 20],
#  ['age', 42],
#  ['age', 27],
#  ['age', 42],
#  ['age', 20],
#  ['age', 24],
#  ['age', 48],
#  ['age', 17],
#  ['age', 17],
#  ['age', 33],
#  ['age', 50],
#  ['age', 22],
#  ['age', 17],
#  ['age', 32],
#  ['age', 31],
#  ['age', 58],
#  ['age', 29],
#  ['age', 37],
#  ['age', 34],
#  ['age', 23],
#  ['age', 18],
#  ['age', 34],
#  ['age', 66],
#  ['age', 45],
#  ['age', 41],
#  ['age', 26],
#  ['age', 54],
#  ['age', 24],
#  ['age', 42],
#  ['age', 20],
#  ['age', 23],
#  ['age', 25],
#  ['age', 35],
#  ['age', 31],
#  ['age', 30],
#  ['age', 19],
#  ['age', 36],
#  ['age', 31],
#  ['age', 21],
#  ['age', 31],
#  ['age', 46],
#  ['age', 44],
#  ['age', 40],
#  ['age', 45],
#  ['age', 60],
#  ['age', 18],
#  ['age', 28],
#  ['age', 36],
#  ['age', 36],
#  ['age', 40],
#  ['age', 36],
#  ['age', 31],
#  ['age', 33],
#  ['age', 19],
#  ['age', 22],
#  ['age', 34],
#  ['age', 33],
#  ['age', 41],
#  ['age', 29],
#  ['age', 50],
#  ['age', 42],
#  ['age', 43],
#  ['age', 44],
#  ['age', 20],
#  ['age', 31],
#  ['age', 65],
#  ['age', 23],
#  ['age', 55],
#  ['age', 26],
#  ['age', 25],
#  ['age', 45],
#  ['age', 35],
#  ['age', 36],
#  ['age', 43],
#  ['age', 56],
#  ['age', 42],
#  ['age', 19],
#  ['age', 55],
#  ['age', 42],
#  ['age', 26],
#  ['age', 17],
#  ['age', 42],
#  ['age', 55],
#  ['age', 32],
#  ['age', 29],
#  ['age', 46],
#  ['age', 29],
#  ['age', 22],
#  ['age', 58],
#  ['age', 23],
#  ['age', 39],
#  ['age', 27],
#  ['age', 54],
#  ['age', 33],
#  ['age', 46],
#  ['age', 37],
#  ['age', 36],
#  ['age', 59],
#  ['age', 34],
#  ['age', 53],
#  ['age', 51],
#  ['age', 32],
#  ['age', 31],
#  ['age', 22],
#  ['age', 47],
#  ['age', 32],
#  ['age', 26],
#  ['age', 37],
#  ['age', 31],
#  ['age', 37],
#  ['age', 55],
#  ['age', 23],
#  ['age', 36],
#  ['age', 34],
#  ['age', 43],
#  ['age', 54],
#  ['age', 43],
#  ['age', 28],
#  ['age', 40],
#  ['age', 41],
#  ['age', 40],
#  ['age', 42],
#  ['age', 61],
#  ['age', 18],
#  ['age', 59],
#  ['age', 21],
#  ['age', 48],
#  ['age', 41],
#  ['age', 18],
#  ['age', 23],
#  ['age', 60],
#  ['age', 22],
#  ['age', 61],
#  ['age', 25],
#  ['age', 46],
#  ['age', 43],
#  ['age', 43],
#  ['age', 24],
#  ['age', 68],
#  ['age', 31],
#  ['age', 17],
#  ['age', 32],
#  ['age', 50],
#  ['age', 33],
#  ['age', 64],
#  ['age', 20],
#  ['age', 30],
#  ['age', 22],
#  ['age', 43],
#  ['age', 22],
#  ['age', 17],
#  ['age', 47],
#  ['age', 41],
#  ['age', 56],
#  ['age', 64],
#  ['age', 47],
#  ['age', 48],
#  ['age', 31],
#  ['age', 29],
#  ['age', 30],
#  ['age', 32],
#  ['age', 57],
#  ['age', 62],
#  ['age', 39],
#  ['age', 43],
#  ['age', 24],
#  ['age', 42],
#  ['age', 53],
#  ['age', 26],
#  ['age', 73],
#  ['age', 72],
#  ['age', 55],
#  ['age', 25],
#  ['age', 41],
#  ['age', 24],
#  ['age', 63],
#  ['age', 17],
#  ['age', 35],
#  ['age', 51],
#  ['age', 62],
#  ['age', 55],
#  ['age', 43],
#  ['age', 40],
#  ['age', 37],
#  ['age', 39],
#  ['age', 31],
#  ['age', 61],
#  ['age', 26],
#  ['age', 46],
#  ['age', 26],
#  ['age', 48],
#  ['age', 34],
#  ['age', 34],
#  ['age', 59],
#  ['age', 34],
#  ['age', 49],
#  ['age', 18],
#  ['age', 43],
#  ['age', 48],
#  ['age', 28],
#  ['age', 33],
#  ['age', 24],
#  ['age', 21],
#  ['age', 17],
#  ['age', 39],
#  ['age', 29],
#  ['age', 44],
#  ['age', 24],
#  ['age', 71],
#  ['age', 51],
#  ['age', 55],
#  ['age', 41],
#  ['age', 23],
#  ['age', 38],
#  ['age', 39],
#  ['age', 19],
#  ['age', 49],
#  ['age', 32],
#  ['age', 27],
#  ['age', 38],
#  ['age', 33],
#  ['age', 63],
#  ['age', 23],
#  ['age', 33],
#  ['age', 54],
#  ['age', 29],
#  ['age', 48],
#  ['age', 35],
#  ['age', 28],
#  ['age', 37],
#  ['age', 42],
#  ['age', 40],
#  ['age', 47],
#  ['age', 22],
#  ['age', 30],
#  ['age', 28],
#  ['age', 63],
#  ['age', 51],
#  ['age', 22],
#  ['age', 27],
#  ['age', 35],
#  ['age', 46],
#  ['age', 37],
#  ['age', 24],
#  ['age', 37],
#  ['age', 53],
#  ['age', 27],
#  ['age', 38],
#  ['age', 53],
#  ['age', 34],
#  ['age', 23],
#  ['age', 39],
#  ['age', 43],
#  ['age', 67],
#  ['age', 81],
#  ['age', 21],
#  ['age', 23],
#  ['age', 25],
#  ['age', 42],
#  ['age', 38],
#  ['age', 64],
#  ['age', 32],
#  ['age', 37],
#  ['age', 51],
#  ['age', 22],
#  ['age', 33],
#  ['age', 42],
#  ['age', 19],
#  ['age', 51],
#  ['age', 23],
#  ['age', 37],
#  ['age', 37],
#  ['age', 47],
#  ['age', 41],
#  ['age', 33],
#  ['age', 31],
#  ['age', 31],
#  ['age', 35],
#  ['age', 38],
#  ['age', 18],
#  ['age', 20],
#  ['age', 54],
#  ['age', 40],
#  ['age', 36],
#  ['age', 43],
#  ['age', 44],
#  ['age', 44],
#  ['age', 43],
#  ['age', 51],
#  ['age', 18],
#  ['age', 51],
#  ['age', 41],
#  ['age', 44],
#  ['age', 33],
#  ['age', 33],
#  ['age', 42],
#  ['age', 25],
#  ['age', 32],
#  ['age', 32],
#  ['age', 36],
#  ['age', 28],
#  ['age', 20],
#  ['age', 35],
#  ['age', 55],
#  ['age', 48],
#  ['age', 36],
#  ['age', 34],
#  ['age', 28],
#  ['age', 67],
#  ['age', 37],
#  ['age', 44],
#  ['age', 25],
#  ['age', 21],
#  ['age', 40],
#  ['age', 78],
#  ['age', 34],
#  ['age', 49],
#  ['age', 22],
#  ['age', 23],
#  ['age', 60],
#  ['age', 45],
#  ['age', 63],
#  ['age', 41],
#  ['age', 47],
#  ['age', 44],
#  ['age', 51],
#  ['age', 46],
#  ['age', 41],
#  ['age', 50],
#  ['age', 47],
#  ['age', 35],
#  ['age', 56],
#  ['age', 45],
#  ['age', 48],
#  ['age', 40],
#  ['age', 39],
#  ...]

# %%
test = trainDataFrame.loc[trainDataFrame["workclass"] == " ?"]
print(test)
# Out:
# Empty DataFrame
# Columns: [age, workclass, education, marital-status, occupation, relationship, race, sex, capital-gain, capital-loss, hours-per-week, native-country, 50k]
# Index: []

# %%
from sklearn.ensemble import RandomForestClassifier 
from sklearn import tree
from sklearn.impute import SimpleImputer
import numpy
import pandas as panda

##########
# TASK 1 #
##########
column_names = ['age', 'workclass', 'education', 'marital-status', 
            'occupation', 'relationship', 'race', 'sex', 'capital-gain', 
            'capital-loss', 'hours-per-week', 'native-country', '50k']
#trainDataFrame = panda.read_csv("/home/chufu/Documents/fall2019/cs464/homework/project3/census-data/adult_train.txt", sep = ",", header = None, names = ["age", "workclass", "education", "marital-status", "occupation", "relationship", "race", "sex", "capital-gain", "capital-loss", "hours-per-week", "native-country"])
#testDataFrame = panda.read_csv("/home/chufu/Documents/fall2019/cs464/homework/project3/census-data/adult_test.txt", sep = ",", header = None, names = ["age", "workclass", "education", "marital-status", "occupation", "relationship", "race", "sex", "capital-gain", "capital-loss", "hours-per-week", "native-country"])
trainDataFrame = panda.read_csv("/home/chufu/Documents/fall2019/cs464/homework/project3/census-data/adult_train.txt", header = None, na_values=" ?").copy()
testDataFrame = panda.read_csv("/home/chufu/Documents/fall2019/cs464/homework/project3/census-data/adult_test.txt", header = None, na_values= " ?").copy()
#featuresDataFrame = panda.read_csv("/home/chufu/Documents/fall2019/cs464/homework/project3/census-data/features.txt", sep = "\t", engine="python", header = None)
featuresDataFrame = panda.read_csv("/home/chufu/Documents/fall2019/cs464/homework/project3/census-data/features.txt", sep = ":,|_", engine="python", header = None).copy()
trainDataFrame.columns = column_names
testDataFrame.columns = column_names

new_feature_values = []
j = 0
for i in trainDataFrame["age"]:
    if trainDataFrame.at[j, "age"] == " ?":
        item = ["age", trainDataFrame.at[j, "age"]]
        new_feature_values.append(item)
    j+=1
# Out:
# yes

# %%
##########
# TASK 1 #
##########
column_names = ['age', 'workclass', 'education', 'marital-status', 
            'occupation', 'relationship', 'race', 'sex', 'capital-gain', 
            'capital-loss', 'hours-per-week', 'native-country', '50k']
#trainDataFrame = panda.read_csv("/home/chufu/Documents/fall2019/cs464/homework/project3/census-data/adult_train.txt", sep = ",", header = None, names = ["age", "workclass", "education", "marital-status", "occupation", "relationship", "race", "sex", "capital-gain", "capital-loss", "hours-per-week", "native-country"])
#testDataFrame = panda.read_csv("/home/chufu/Documents/fall2019/cs464/homework/project3/census-data/adult_test.txt", sep = ",", header = None, names = ["age", "workclass", "education", "marital-status", "occupation", "relationship", "race", "sex", "capital-gain", "capital-loss", "hours-per-week", "native-country"])
trainDataFrame = panda.read_csv("/home/chufu/Documents/fall2019/cs464/homework/project3/census-data/adult_train.txt", header = None, na_values=" ?").copy()
testDataFrame = panda.read_csv("/home/chufu/Documents/fall2019/cs464/homework/project3/census-data/adult_test.txt", header = None, na_values= " ?").copy()
#featuresDataFrame = panda.read_csv("/home/chufu/Documents/fall2019/cs464/homework/project3/census-data/features.txt", sep = "\t", engine="python", header = None)
featuresDataFrame = panda.read_csv("/home/chufu/Documents/fall2019/cs464/homework/project3/census-data/features.txt", sep = ":,|_", engine="python", header = None).copy()
trainDataFrame.columns = column_names
testDataFrame.columns = column_names

# %%
trainAgeMean = trainDataFrame["age"].mean()
trainAgeMedian = trainDataFrame["age"].median()

trainCapitalGainMean = trainDataFrame["capital-gain"].mean()
trainCapitalGainMedian = trainDataFrame["capital-gain"].median()

trainCapitalLossMean = trainDataFrame["capital-loss"].mean()
trainCapitalLossMedian = trainDataFrame["capital-loss"].median()

trainHrPerWeekMean = trainDataFrame["hours-per-week"].mean()
trainHrPerWeekMedian = trainDataFrame["hours-per-week"].median()

trainWorkclassMode = trainDataFrame["workclass"].mode()

# %%
test = trainDataFrame.loc[trainDataFrame["education"] == " ?"]
print(test)

#trainDataFrame.iat[0, 0]
#trainDataFrame.iat[0, 0] = 2130
#trainDataFrame.iat[0, 0]
# Out:
# Empty DataFrame
# Columns: [age, workclass, education, marital-status, occupation, relationship, race, sex, capital-gain, capital-loss, hours-per-week, native-country, 50k]
# Index: []

# %%
trainDataFrame.isnull().sum()
#trainDataFrame["workclass"].fillna(trainWorkclassMode)
# Out:
# age                  0
# workclass         1836
# education            0
# marital-status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country     583
# 50k                  0
# dtype: int64

# %%
i = 0 # x
l = 0 # y 
for j in trainDataFrame["age"]:
    for k in range(13):
        if trainDataFrame.iat[l, i] == " ?":
            if i == 13:
                break
            if k == 0:
                trainDataFrame.iat[l, i] = trainDataFrame["age"].mean()

            if k == 1:
                trainDataFrame.iat[l, i] = trainDataFrame["workclass"].mode()

            if k == 2:
                trainDataFrame.iat[l, i] = trainDataFrame["education"].mode()

            if k == 3:
                trainDataFrame.iat[l, i] = trainDataFrame["marital-status"].mode()

            if k == 4:
                trainDataFrame.iat[l, i] = trainDataFrame["occupation"].mode()

            if k == 5:
                trainDataFrame.iat[l, i] = trainDataFrame["relationship"].mode()

            if k == 6:
                trainDataFrame.iat[l, i] = trainDataFrame["race"].mode()

            if k == 7:
                trainDataFrame.iat[l, i] = trainDataFrame["sex"].mode()

            if k == 8:
                trainDataFrame.iat[l, i] = trainDataFrame["capital-gain"].mean()

            if k == 9:
                trainDataFrame.iat[l, i] = trainDataFrame["capital-loss"].mean()
                
            if k == 10:
                trainDataFrame.iat[l, i] = trainDataFrame["hours-per-week"].mean()

            if k == 11:
                trainDataFrame.iat[l, i] = trainDataFrame["workclass"].mode()

            if k == 12:
                trainDataFrame.iat[l, i] = trainDataFrame["50k"].mode()
        i+=1
    l+=1
# Out:
# ---------------------------------------------------------------
# IndexError                    Traceback (most recent call last)
# <ipython-input-4-ae1299a0f78f> in <module>
#       3 for j in trainDataFrame["age"]:
#       4     for k in range(13):
# ----> 5         if trainDataFrame.iat[l, i] == " ?":
#       6             if i == 13:
#       7                 break
#
# ~/.local/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    2198
#    2199         key = self._convert_key(key)
# -> 2200         return self.obj._get_value(*key, takeable=self._takeable)
#    2201
#    2202     def __setitem__(self, key, value):
#
# ~/.local/lib/python3.7/site-packages/pandas/core/frame.py in _get_value(self, index, col, takeable)
#    2838
#    2839         if takeable:
# -> 2840             series = self._iget_item_cache(col)
#    2841             return com.maybe_box_datetimelike(series._values[index])
#    2842
#
# ~/.local/lib/python3.7/site-packages/pandas/core/generic.py in _iget_item_cache(self, item)
#    3292         ax = self._info_axis
#    3293         if ax.is_unique:
# -> 3294             lower = self._get_item_cache(ax[item])
#    3295         else:
#    3296             lower = self.take(item, axis=self._info_axis_number)
#
# ~/.local/lib/python3.7/site-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    4278         if is_scalar(key):
#    4279             key = com.cast_scalar_indexer(key)
# -> 4280             return getitem(key)
#    4281
#    4282         if isinstance(key, slice):
#
# IndexError: index 13 is out of bounds for axis 0 with size 13

# %%
#featuresDataFrame[1].describe()
#featuresDataFrame[0][0]
#for i in featuresDataFrame[0]:
  #  print("--"+ i)
#featuresDataFrame.info()

test = trainDataFrame.loc[trainDataFrame["workclass"] == " ?"]
print(test)
# Out:
#        age workclass      education          marital-status occupation  \
# 27      54         ?   Some-college      Married-civ-spouse          ?
# 61      32         ?        7th-8th   Married-spouse-absent    87.3038
# 69      25         ?   Some-college           Never-married          ?
# 77      67         ?           10th      Married-civ-spouse          ?
# 106     17         ?           10th           Never-married          ?
# ...    ...       ...            ...                     ...        ...
# 32530   35         ?      Bachelors      Married-civ-spouse          ?
# 32531   30         ?      Bachelors           Never-married          ?
# 32539   71         ?      Doctorate      Married-civ-spouse          ?
# 32541   41         ?        HS-grad               Separated          ?
# 32542   72         ?        HS-grad      Married-civ-spouse          ?
#
#          relationship                 race      sex  capital-gain  \
# 27            Husband   Asian-Pac-Islander     Male             0
# 61      Not-in-family                White     Male             0
# 69          Own-child                White     Male             0
# 77            Husband                White     Male             0
# 106         Own-child                White   Female         34095
# ...               ...                  ...      ...           ...
# 32530            Wife                White   Female             0
# 32531   Not-in-family   Asian-Pac-Islander   Female             0
# 32539         Husband                White     Male             0
# 32541   Not-in-family                Black   Female             0
# 32542         Husband                White     Male             0
#
#        capital-loss  hours-per-week  native-country     50k
# 27                0              60           South    >50K
# 61                0              40               ?   <=50K
# 69                0              40   United-States   <=50K
# 77                0               2   United-States   <=50K
# 106               0              32   United-States   <=50K
# ...             ...             ...             ...     ...
# 32530             0              55   United-States    >50K
# 32531             0              99   United-States   <=50K
# 32539             0              10   United-States    >50K
# 32541             0              32   United-States   <=50K
# 32542             0              25   United-States   <=50K
#
# [1836 rows x 13 columns]

# %%
##########
# TASK 2 #
##########
# column names are essentially the feature
#feature_len = len(column_names)

workclass = ["workclass", "Private", "Self-emp-not-inc", "Self-emp-inc", "Federal-gov", "Local-gov", "State-gov", "Without-pay", "Never-worked"]
education = ["education", "Bachelors", "Some-college", "11th", "HS-grad", "Prof-school", "Assoc-acdm", "Assoc-voc", "9th", "7th-8th", "12th", "Masters", "1st-4th", "10th", "Doctorate", "5th-6th", "Preschool"]
marital_status = ["marital-status", "Married-civ-spouse", "Divorced", "Never-married", "Separated", "Widowed", "Married-spouse-absent", "Married-AF-spouse"]
occupation = ["occupation", "Tech-support", "Craft-repair", "Other-service", "Sales", "Exec-managerial", "Prof-specialty", "Handlers-cleaners", "Machine-op-inspct", "Adm-clerical", "Farming-fishing", "Transport-moving", "Priv-house-serv", "Protective-serv", "Armed-Forces"]
relationship = ["relationship", "Wife", "Own-child", "Husband", "Not-in-family", "Other-relative", "Unmarried"]
race = ["race", "White", "Asian-Pac-Islander", "Amer-Indian-Eskimo", "Other", "Black"]
sex = ["sex", "Female", "Male"]
native_country = ["native-country", "United-States", "Cambodia", "England", "Puerto-Rico", "Canada", "Germany", "Outlying-US(Guam-USVI-etc)", "India", "Japan", "Greece", "South", "China", "Cuba", "Iran", "Honduras", "Philippines", "Italy", "Poland", "Jamaica", "Vietnam", "Mexico", "Portugal", "Ireland", "France", "Dominican-Republic", "Laos", "Ecuador", "Taiwan", "Haiti", "Columbia", "Hungary", "Guatemala", "Nicaragua", "Scotland", "Thailand", "Yugoslavia", "El-Salvador", "Trinadad&Tobago", "Peru", "Hong", "Holand-Netherlands"]

new_features = []

j = 0

for i in featuresDataFrame[0]:
    if i == featuresDataFrame[0][0] or i == featuresDataFrame[0][8] or i == featuresDataFrame[0][9] or i == featuresDataFrame[0][10]:
        new_features.append(i)
        
for i in workclass:
    if j > (len(workclass) - 1):
        j = 1
        break
    e = workclass[0] + ":" + workclass[j]
    new_features.append(e)
    j+=1
    
for i in education:
    if j > (len(education) - 1):
        j = 1
        break
    e = education[0] + ":" + education[j]
    new_features.append(e)
    j+=1
    
for i in marital_status:
    if j > (len(marital_status) - 1):
        j = 1
        break
    e = marital_status[0] + ":" + marital_status[j]
    new_features.append(e)
    j+=1
    
for i in occupation:
    if j > (len(occupation) - 1):
        j = 1
        break
    e = occupation[0] + ":" + occupation[j]
    new_features.append(e)
    j+=1
    
for i in relationship:
    if j > (len(relationship) - 1):
        j = 1
        break
    e = relationship[0] + ":" + relationship[j]
    new_features.append(e)
    j+=1
    
for i in race:
    if j > (len(race) - 1):
        j = 1
        break
    e = race[0] + ":" + race[j]
    new_features.append(e)
    j+=1
    
for i in sex:
    if j > (len(sex) - 1):
        j = 1
        break
    e = sex[0] + ":" + sex[j]
    new_features.append(e)
    j+=1
    
for i in native_country:
    if j > (len(native_country) - 1):
        j = 1
        break
    e = native_country[0] + ":" + native_country[j]
    new_features.append(e)
    j+=1

# %%
new_features
# Out:
# ['age: continuous.',
#  'capital-gain: continuous.',
#  'capital-loss: continuous.',
#  'hours-per-week: continuous.',
#  'workclass:workclass',
#  'workclass:Private',
#  'workclass:Self-emp-not-inc',
#  'workclass:Self-emp-inc',
#  'workclass:Federal-gov',
#  'workclass:Local-gov',
#  'workclass:State-gov',
#  'workclass:Without-pay',
#  'workclass:Never-worked',
#  'education:7th-8th',
#  'education:12th',
#  'education:Masters',
#  'education:1st-4th',
#  'education:10th',
#  'education:Doctorate',
#  'education:5th-6th',
#  'education:Preschool',
#  'marital-status:Married-civ-spouse',
#  'marital-status:Divorced',
#  'marital-status:Never-married',
#  'marital-status:Separated',
#  'marital-status:Widowed',
#  'marital-status:Married-spouse-absent',
#  'marital-status:Married-AF-spouse',
#  'occupation:Tech-support',
#  'occupation:Craft-repair',
#  'occupation:Other-service',
#  'occupation:Sales',
#  'occupation:Exec-managerial',
#  'occupation:Prof-specialty',
#  'occupation:Handlers-cleaners',
#  'occupation:Machine-op-inspct',
#  'occupation:Adm-clerical',
#  'occupation:Farming-fishing',
#  'occupation:Transport-moving',
#  'occupation:Priv-house-serv',
#  'occupation:Protective-serv',
#  'occupation:Armed-Forces',
#  'relationship:Wife',
#  'relationship:Own-child',
#  'relationship:Husband',
#  'relationship:Not-in-family',
#  'relationship:Other-relative',
#  'relationship:Unmarried',
#  'race:White',
#  'race:Asian-Pac-Islander',
#  'race:Amer-Indian-Eskimo',
#  'race:Other',
#  'race:Black',
#  'sex:Female',
#  'sex:Male',
#  'native-country:United-States',
#  'native-country:Cambodia',
#  'native-country:England',
#  'native-country:Puerto-Rico',
#  'native-country:Canada',
#  'native-country:Germany',
#  'native-country:Outlying-US(Guam-USVI-etc)',
#  'native-country:India',
#  'native-country:Japan',
#  'native-country:Greece',
#  'native-country:South',
#  'native-country:China',
#  'native-country:Cuba',
#  'native-country:Iran',
#  'native-country:Honduras',
#  'native-country:Philippines',
#  'native-country:Italy',
#  'native-country:Poland',
#  'native-country:Jamaica',
#  'native-country:Vietnam',
#  'native-country:Mexico',
#  'native-country:Portugal',
#  'native-country:Ireland',
#  'native-country:France',
#  'native-country:Dominican-Republic',
#  'native-country:Laos',
#  'native-country:Ecuador',
#  'native-country:Taiwan',
#  'native-country:Haiti',
#  'native-country:Columbia',
#  'native-country:Hungary',
#  'native-country:Guatemala',
#  'native-country:Nicaragua',
#  'native-country:Scotland',
#  'native-country:Thailand',
#  'native-country:Yugoslavia',
#  'native-country:El-Salvador',
#  'native-country:Trinadad&Tobago',
#  'native-country:Peru',
#  'native-country:Hong',
#  'native-country:Holand-Netherlands']
